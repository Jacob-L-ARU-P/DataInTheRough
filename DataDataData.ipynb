# %%
# Builder Block; Imports modules and does some basic setup stuff
# for the rest of the Notebook.

import numpy as np
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %% [markdown]
# Words words words

# %%
# Import Data/Data Sets

#sampleData = pd.read_csv('K:\JL Week 13\SSID-2213276-DAA-ItDSaP\Data_Analysis\Data_Evaluation\Datasets\Raw\World Population (2022).csv')

Data_Kaggle_WP2022 = pd.read_csv('K:\JL Week 13\SSID-2213276-DAA-ItDSaP\Data_Analysis\Data_Evaluation\Datasets\Raw Work Copies\World Population (2022).csv')
Data_Kaggle_GLE = pd.read_csv('K:\JL Week 13\SSID-2213276-DAA-ItDSaP\Data_Analysis\Data_Evaluation\Datasets\Raw Work Copies\global life expectancy dataset.csv')
Data_UNWP1950_2000 = pd.read_csv('K:\JL Week 13\SSID-2213276-DAA-ItDSaP\Data_Analysis\Data_Evaluation\Datasets\Raw Work Copies\wUNdata_Export_20221129_184105046.csv')
Data_UNWP1970_2020 = pd.read_csv('K:\JL Week 13\SSID-2213276-DAA-ItDSaP\Data_Analysis\Data_Evaluation\Datasets\Raw Work Copies\wUNdata_Export_20221129_184326975.csv')
Data_UNMF1980_2013 = pd.read_csv('K:\JL Week 13\SSID-2213276-DAA-ItDSaP\Data_Analysis\Data_Evaluation\Datasets\Raw Work Copies\wUNdesa_pd_2015_MF_totals.csv')

print("\tDataset(s) Loaded.")
# Out:
# 	Dataset(s) Loaded.

# %%
# Quick Access:

#sampleData     # Displays Data in Table, first 5 rows & last 5 rows.

#sampleData.head(8)  # Displays the first 8 rows

#sampleData.info() # Displays information on column headers and their associated data type

# %%
# sbn.catplot(data=Data_Kaggle_WP2022, kind= 'box', x= 'Country (or dependency)', y= 'Population (2022)', aspect=5)
#Data_UNWP1950_2000.groupby('Country or Area')['Value'].describe()

#sbn.catplot(data=Data_UNWP1950_2000, kind= 'box', x= 'Year(s)', y= 'Value', aspect= 2)

Data_UNWP1950_2000_Afgan = Data_UNWP1950_2000[Data_UNWP1950_2000['Country or Area'] == 'Afghanistan'].copy()

sbn.relplot(data=Data_UNWP1950_2000_Afgan, x= 'Year(s)', y= 'Value', aspect= 3)
